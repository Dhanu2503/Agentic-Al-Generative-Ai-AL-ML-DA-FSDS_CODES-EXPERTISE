# %%
# Types of programming languages
# Translator
# Compiled and Interpreted lanaguages
# How a Python program gets executed
# Variable and Constant

# %% [markdown]
# # Types of programming languages

# %% [markdown]
# - 1- Hilgh level language
# - 2- Low level language

# %% [markdown]
# # High level language

# %% [markdown]
# - It is a human friendly computer language.
# - The code is written in simple language like English.
# - It is easy to read, learn and understand.
# - **Examples-** C, C++, Python, Java, PHP, R etc.

# %% [markdown]
# # Low level language

# %% [markdown]
# - It is machine friendly.
# - The code is writting using binary digits also known as bits (0,1)
# - It is almost impossible to learn and understand for a human being.
# - **Example-** Machine language is a low level language. It is also known as Binary language
# - 0 and 1 are just signals

# %%
# 10010010100100
# 10010010010010
# 10010111100101
# 10010010011111

# %% [markdown]
# # Translator

# %% [markdown]
# - A translator is a software that converts the high level language code into machine code and vice versa.

# %% [markdown]
# # Types of translators

# %% [markdown]
# - 1- Compiler
# - 2- Interpreter

# %% [markdown]
# # Compiler

# %% [markdown]
# - The compiler reads the whole high level language code first and then it converts the whole code into machine code at once.

# %% [markdown]
# # Interpreter

# %% [markdown]
# - It reads the high level language  code line by line and converts into machine code line by line.
# - It reads and converts one line at a time.

# %% [markdown]
# # Compiled vs Interpreted languages

# %% [markdown]
# - The languages that use compiler as the translator are known as the compiled languages.
# - C, C++, Java, VB etc.

# %% [markdown]
# - The languages that use interpreter as the translator are known as interpreted languages.
# - Python, R, Ruby, PHP etc.

# %% [markdown]
# # Whether Python is interpreted or compiled?

# %% [markdown]
# # How a Python program gets executed

# %%
#include<stdio.h>
int aa`main()
{
    int a=10,b=20,c;
    c=a+b;
    print("%d",c);
    return 0;
    }
# Out:
#   Cell In[3], line 2
#     int main()
#         ^
# SyntaxError: invalid syntax

# %%
print(10+20)
# Out:
# 30

# %% [markdown]
# # Source Code

# %% [markdown]
# - The code that we write as a developer is known as source code.
# - The extension of the Python source code is .py

# %% [markdown]
# # Intermediate Code

# %% [markdown]
# - As soon as we run the Python source code, compiler comes into picture.
# - The compiler converts the source code  into intermediate code.
# - The intermediate code in Python is known as Bytecode
# - The extension of Python Bytecode file is .pyc
# - If compiler catches any error in source code then Bytecode is not generated. In this case the whole program is not executed and we don't get any output.

# %% [markdown]
# # Machine Code

# %% [markdown]
# - As soon as compiler generates the Bytecode the interpreter comes into picture.
# - The interpreter reads and converts the Bytecode into machine code line by line.
# - As soon as interpreter catches any error then it stops execution.
# - In this case the program is partially executed. Until the interpreter catches any error, it generates the output.

# %% [markdown]
# # Types of errors

# %% [markdown]
# - 1- Compile time error
# - 2- Run time error

# %% [markdown]
# # Compile time errors

# %% [markdown]
# - The errors that are caught by the compiler at the time of compilation are known as compile time errors.

# %% [markdown]
# ### Examples

# %% [markdown]
# - Syntax error
# - Indentation error

# %% [markdown]
# # Run time errors

# %% [markdown]
# - The errors that are caught by the interpreter at the run time are known as run time errors.

# %% [markdown]
# ### Examples

# %% [markdown]
# - 1- Name error
# - 2- Type error
# - 3- Value error
# - 4- Index error
# - 5- File not found error
# - 6- Stop Iteration
# - 7- Key error
# - etc.

# %%
Syntax error

# %%
Name error

# %%
Name error

Syntax error

# %%
print('Hello')
a=10
b=20
c=a+b
print(c
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp\ipykernel_38716\1691340000.py", line 5
#     print(c
#            ^
# SyntaxError: unexpected EOF while parsing

# %%
print('Hello')
a=10
b=20
c=a+b
print(c)
print(d) # Name error
print('Hello Python')
print('Thanks')
# Out:
# Hello
# 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 c=a+b
#       5 print(c)
# ----> 6 print(d) # Name error
#       7 print('Hello Python')
#       8 print('Thanks')
#
# NameError: name 'd' is not defined

# %%
print('Hello')
a=10
b=20
c=a+b
print(c)
print(d) # Name error
print('Hello Python')
print('Thanks'
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp\ipykernel_38716\4092832761.py", line 8
#     print('Thanks'
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
# Python has been developed in C language
# ABC language- Interpreted

# %%
# Compiled languages- better performance
# Interpreted languages- lower performnace- Easy syntax

# %% [markdown]
# # Variable and constant

# %% [markdown]
# # Variable (name)

# %% [markdown]
# - A variable is a container that contains some value.

# %% [markdown]
# # Constant (value)

# %% [markdown]
# - The value that a variable holds is a constant

# %%
a=10
# a- variable
# 10- constant (value)

# %%
age=25
# age- variable
# 25- value (constant)

# %%
0=34
print(0)
# Out:
#   File "C:\Users\kanna\AppData\Local\Temp\ipykernel_18672\3839629154.py", line 1
#     0=34
#     ^
# SyntaxError: cannot assign to literal

# %%
_0=34
print(_0)
# Out:
# 34

# %%
_a_a=10
print(_a_a)
# Out:
# 10

# %% [markdown]
# # Datatypes

# %% [markdown]
# - A datatype is a type identifier of the value that a variable holds.
# - Different kind of values will have different behaviour so it is important to know the type of a value.

# %%
# type()- It gives the type of the value that a variable holds

# %%
# Basis datatypes
# Derived datatypes

# %% [markdown]
# # Basic Datatypes

# %% [markdown]
# # integer- int

# %%
# Any number whether it is +ive, -ive or 0 without a decimal point is an int value.

# %%
a=10000
print(a)
print(type(a))
# Out:
# 10000
# <class 'int'>

# %%
a=10
print(a,type(a))
# Out:
# 10 <class 'int'>

# %%
a=-5
print(a,type(a))
# Out:
# -5 <class 'int'>

# %%
a=0
print(a,type(a))
# Out:
# 0 <class 'int'>

# %% [markdown]
# # float

# %%
# - Any number whetehr +ive, -ive or 0 with a decimal point is a float value

# %%
a=2.5
print(a,type(a))
# Out:
# 2.5 <class 'float'>

# %%
a=-3.6
print(a,type(a))
# Out:
# -3.6 <class 'float'>

# %%
a=0.0
print(a,type(a))
# Out:
# 0.0 <class 'float'>

# %% [markdown]
# # complex

# %%
# - Any number in the form of a+bj is a complex value.
# - Where a is a real number and bj is an imaginary number.

# %%
a=5+7j
print(a,type(a))
print(id(a))
# Out:
# (5+7j) <class 'complex'>
# 2685609113360

# %%
a=2.5+3.2j
print(a,type(a))
print(abs(a))
# Out:
# (2.5+3.2j) <class 'complex'>
# 4.060788100849391

# %%
a=9+2j
print(a)
print(a.real)
print(a.imag)
# Out:
# (9+2j)
# 9.0
# 2.0

# %%
a=5j
print(a,type(a))
# Out:
# 5j <class 'complex'>

# %%
a=5+2i
print(a)
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp\ipykernel_38716\4281827626.py", line 1
#     a=5+2i
#          ^
# SyntaxError: invalid syntax

# %%
a=-10+6j
print(a)
print(abs(a))
# Out:
# (-10+6j)
# 11.661903789690601

# %%
a=-5+2j
print(a,type(a))
# Out:
# (-5+2j) <class 'complex'>

# %% [markdown]
# # string- str

# %%
# Anything inside the ' ', " ",''' ''', """ """ is a string value

# %%
a='5'
print(a,type(a))
# Out:
# 5 <class 'str'>

# %%
a='Python'
print(a,type(a))
# Out:
# Python <class 'str'>

# %%
a="Python"
print(a,type(a))
# Out:
# Python <class 'str'>

# %%
# Output- Python's Libraries

a="Python's Libraies"
print(a)
# Out:
# Python's Librraies

# %%
a='2.5'
print(a,type(a))
# Out:
# 2.5 <class 'str'>

# %%
a='this is me'
print(a)
# Out:
# this is me

# %%
v="We are learning 'Data Scinece' from Learnbay"
print(v)
# Out:
# We are learning 'Data Scinece' from Learnbay

# %%
# Output- We are learning "Data Science" from Learnbay

a='We are learning "Data Scinece" from Learnbay'
print(a)
# Out:
# We are learning "Data Scinece" from Learnbay

# %%
a='''Hello world!
This is Python class'''

print(a)
# Out:
# Hello world!
# This is Python class

# %%
a="""Hello world!
This is Python class"""
print(a)
# Out:
# Hello world!
# This is Python class

# %%
# Hello world!
# This is "Python class"

# %%
a='''Hello world!
This is "Python class"'''
print(a)
# Out:
# Hello world!
# This is "Python class"

# %%
# 'Hello world!
# This is Python class'

# %%
a="""'Hello world!
This is Python class'"""
print(a)
# Out:
# 'Hello world!
# This is Python class'

# %% [markdown]
# # Boolean- bool

# %%
# True and False are the boolean values

# %%
a=True
print(a,type(a))
# Out:
# True <class 'bool'>

# %%
a=False
print(a,type(a))
# Out:
# False <class 'bool'>

# %%
m="kanjjsf'jdwdgj'jsfsjfna"
print(m)
# Out:
# kanjjsf'jdwdgj'jsfsjfna

# %%
print("hello world")
# Out:
# hello world

# %%
a=None
print(a,type(a))
# Out:
# None <class 'NoneType'>

# %%
distance=395000
time=9000
speed=distance/time
print(speed)
# Out:
# 43.888888888888886

# %%
a=2*2*2+2*2*3+2*3*2
print(a)
# Out:
# 32

# %%
print("kannan")
# Out:
# kannan

# %%
print("kannan")
print("kannan")
print("kannan")
# Out:
# kannan
# kannan
# kannan

# %%
import numpy as np

# %%
len(np.random.randint(10,11,10000))
# Out:
# 10000

# %%
'2'+chr(189)
# Out:
# '2½'

# %%
100 and 20
# Out:
# 20

# %%
100 or 20
# Out:
# 100

# %%
print(15 & 26)
# Out:
# 10

# %%
print(15 | 26)
print(15 ^ 26)
print(~26)
print(3 << 4)
print(4 >> 2)
# Out:
# 31
# 21
# -27
# 48
# 1

# %%
print("kannadhsan")
# Out:
# kannadhsan

# %%
print("kannadhsan")
print("kannadhsan")
print("kannadhsan")
# Out:
# kannadhsan
# kannadhsan
# kannadhsan

# %%
if 6==6:
    print("yes")
# Out:
# yes

# %%
 print()

# %%
import numpy as np
oo=np.random.randint(1,100,16).reshape(4,4)
print(oo)
# Out:
# [[96 41 97 94]
#  [45 72 45  1]
#  [42  8 59 97]
#  [49 93 39 92]]

# %%
if 7==7:
    print("hello")
# Out:
# hello

# %%
print(10)
# Out:
# 10

# %% [markdown]
# # None

# %%
# name="kanna"
# roll_number=None
# city="chenni"
# print(name,roll_number,city)
# Out:
# 'name="kanna"\nroll_number=None\ncity="chenni"\nprint(name,roll_number,city)'

# %%
#print("airtel")

# %%
aa=True
print(aa)
# Out:
# True

# %%
ff=None
ii=bool(ff)
ii
# Out:
# False
