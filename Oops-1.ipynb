# %% [markdown]
# #   Class
# - A class is a blueprint or template for creating objects.
# - It defines attributes (variables) and methods (functions) that the objects created from the class will have.

# %%
class Car:
    # attributes
    wheels = 4

    # method
    def start(self):
        print("Car has started")

# %% [markdown]
# # Object
#
# - An object is an instance of a class.
# - It is created from the class and represents a real-world entity.
# - Multiple objects can be created from a single class.

# %%
# creating objects
car1 = Car()
car2 = Car()

print(car1.wheels)  # 4
car1.start()         # Car has started
# Out:
# 4
# Car has started

# %% [markdown]
# # Constructor
#
# - A constructor is a special method that is automatically called when an object is created.
# - In Python, it is defined using __init__().
# - It is mainly used to initialize object attributes.

# %%
class Car:
    def __init__(self, brand, color):
        self.brand = brand      # instance variable
        self.color = color

    def show(self):
        print(f"Brand: {self.brand}, Color: {self.color}")

# creating objects with constructor
car1 = Car("Toyota", "Red")
car2 = Car("BMW", "Black")

car1.show()
car2.show()
# Out:
# Brand: Toyota, Color: Red
# Brand: BMW, Color: Black

# %%
class Student:
    def __init__(self, name, roll, marks):
        self.name = name
        self.roll = roll
        self.marks = marks
    
    def display(self):
        print(f"Name: {self.name}, Roll: {self.roll}, Marks: {self.marks}")

s1 = Student("Naveen", 101, 85)
s2 = Student("Priya", 102, 92)

s1.display()
s2.display()
# Out:
# Name: Naveen, Roll: 101, Marks: 85
# Name: Priya, Roll: 102, Marks: 92

# %%
class BankAccount:
    def __init__(self, account_holder, account_number, balance=0):
        self.account_holder = account_holder
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} deposited. New Balance: {self.balance}")
    
    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
            print(f"{amount} withdrawn. Remaining Balance: {self.balance}")
        else:
            print("Insufficient Balance!")

acc1 = BankAccount("Naveen", 12345, 5000)
acc2 = BankAccount("Priya", 67890, 10000)

acc1.deposit(2000)
acc1.withdraw(3000)

acc2.withdraw(12000)
# Out:
# 2000 deposited. New Balance: 7000
# 3000 withdrawn. Remaining Balance: 4000
# Insufficient Balance!

# %%
class Cab:
    def __init__(self, driver, car_number, status="Available"):
        self.driver = driver
        self.car_number = car_number
        self.status = status

    def book_cab(self):
        if self.status == "Available":
            self.status = "Booked"
            print(f"Cab {self.car_number} driven by {self.driver} is now Booked.")
        else:
            print(f"Cab {self.car_number} is already booked.")

cab1 = Cab("Ravi", "KA05AB1234")
cab2 = Cab("Arun", "KA09CD5678")

cab1.book_cab()
cab1.book_cab()
cab2.book_cab()
cab2.book_cab()
# Out:
# Cab KA05AB1234 driven by Ravi is now Booked.
# Cab KA05AB1234 is already booked.
# Cab KA09CD5678 driven by Arun is now Booked.
# Cab KA09CD5678 is already booked.
